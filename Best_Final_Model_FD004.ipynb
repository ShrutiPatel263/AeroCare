# %% [markdown]
# <a href="https://colab.research.google.com/github/ShrutiPatel263/AeroCare/blob/main/Best_Final_Model_FD004.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================================
# RUL PREDICTION — Gated Ensemble BiLSTM + Attention
# v3: Selective fixes only
#   ✅ KEPT from original: threshold=125, architecture, all hyperparams
#   ✅ KEPT fix: removed duplicate clipping
#   ✅ KEPT fix: ensemble all 5 fold models (biggest gain)
#   ✅ KEPT fix: best fold by MAE not R²
#   ✅ KEPT fix: rebalanced sample weights
#   ❌ REVERTED: threshold change to 150 (hurt performance)
#   ❌ REVERTED: linear bias calibration (distorted predictions)
# ============================================================

# ── Google Drive Mount ────────────────────────────────────────
from google.colab import drive
drive.mount('/content/drive')

# ── Core Imports ──────────────────────────────────────────────
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import warnings
from importlib import reload
from IPython.display import display, HTML

import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.io as pio

warnings.filterwarnings('ignore')

# ── Notebook Display Config ───────────────────────────────────
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 500)
pd.set_option('display.expand_frame_repr', False)
display(HTML(""))
reload(plt)
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# ── Plotly Config ─────────────────────────────────────────────
pio.renderers.default = 'iframe'
pio.templates["ck_template"] = go.layout.Template(
    layout_colorway=px.colors.sequential.Viridis,
    layout_autosize=False,
    layout_width=800,
    layout_height=600,
    layout_font=dict(family="Calibri Light"),
    layout_title_font=dict(family="Calibri"),
    layout_hoverlabel_font=dict(family="Calibri Light"),
)
pio.templates.default = 'ck_template+gridon'

# ── Column Names ──────────────────────────────────────────────
index_names   = ['engine', 'cycle']
setting_names = ['setting_1', 'setting_2', 'setting_3']
sensor_names  = [
    "(Fan inlet temperature) (◦R)",
    "(LPC outlet temperature) (◦R)",
    "(HPC outlet temperature) (◦R)",
    "(LPT outlet temperature) (◦R)",
    "(Fan inlet Pressure) (psia)",
    "(bypass-duct pressure) (psia)",
    "(HPC outlet pressure) (psia)",
    "(Physical fan speed) (rpm)",
    "(Physical core speed) (rpm)",
    "(Engine pressure ratio(P50/P2)",
    "(HPC outlet Static pressure) (psia)",
    "(Ratio of fuel flow to Ps30) (pps/psia)",
    "(Corrected fan speed) (rpm)",
    "(Corrected core speed) (rpm)",
    "(Bypass Ratio)",
    "(Burner fuel-air ratio)",
    "(Bleed Enthalpy)",
    "(Required fan speed)",
    "(Required fan conversion speed)",
    "(High-pressure turbines Cool air flow)",
    "(Low-pressure turbines Cool air flow)"
]
col_names = index_names + setting_names + sensor_names

# ── Load Data ─────────────────────────────────────────────────
df_train    = pd.read_csv('drive/MyDrive/AeroCare-Aircraft maintenance system/CMaps/train_FD004.txt',
                           sep=r'\s+', header=None, index_col=False, names=col_names)
df_test     = pd.read_csv('drive/MyDrive/AeroCare-Aircraft maintenance system/CMaps/test_FD004.txt',
                           sep=r'\s+', header=None, index_col=False, names=col_names)
df_test_RUL = pd.read_csv('drive/MyDrive/AeroCare-Aircraft maintenance system/CMaps/RUL_FD004.txt',
                           sep=r'\s+', header=None, index_col=False, names=['RUL'])

# ── Feature Selection ─────────────────────────────────────────
features_to_keep = [
    'setting_1', 'setting_2',
    "(LPC outlet temperature) (◦R)",
    "(HPC outlet temperature) (◦R)",
    "(LPT outlet temperature) (◦R)",
    "(Fan inlet Pressure) (psia)",
    "(HPC outlet pressure) (psia)",
    "(Engine pressure ratio(P50/P2)",
    "(HPC outlet Static pressure) (psia)",
    "(Ratio of fuel flow to Ps30) (pps/psia)",
    "(Corrected fan speed) (rpm)",
    "(Corrected core speed) (rpm)",
    "(Bypass Ratio)",
    "(Bleed Enthalpy)",
    "(High-pressure turbines Cool air flow)",
    "(Low-pressure turbines Cool air flow)"
]
features = list(features_to_keep)

# ── Add RUL to Training Set ───────────────────────────────────
df_train_RUL = df_train.groupby(['engine']).agg({'cycle': 'max'})
df_train_RUL.rename(columns={'cycle': 'life'}, inplace=True)
df_train = df_train.merge(df_train_RUL, how='left', on=['engine'])
df_train['RUL'] = df_train['life'] - df_train['cycle']
df_train.drop(['life'], axis=1, inplace=True)

# ── Adaptive Clipping — ORIGINAL threshold=125, applied ONCE ─
# FIX: removed duplicate application that was compressing high
# RUL values twice and hurting model learning
def apply_adaptive_clipping(df, threshold=125):
    """Compress high RUL values instead of hard clipping.
    RUL_new = threshold + (RUL_old - threshold) * 0.4  for RUL > threshold
    """
    df = df.copy()
    if 'RUL' in df.columns:
        mask = df['RUL'] > threshold
        df.loc[mask, 'RUL'] = threshold + (df.loc[mask, 'RUL'] - threshold) * 0.4
    return df

# Applied ONCE only (original had this called twice — bug fixed)
df_train = apply_adaptive_clipping(df_train, threshold=125)

# ── Sequence Creation ─────────────────────────────────────────
def create_sequences(df, window_size, stride, engine_col='engine'):
    sequences, targets, engine_ids = [], [], []
    has_rul = 'RUL' in df.columns

    for engine_id in df[engine_col].unique():
        engine_data = df[df[engine_col] == engine_id].sort_values('cycle')
        feat_cols   = [c for c in engine_data.columns
                       if c not in ['engine', 'cycle', 'RUL']]
        values      = engine_data[feat_cols].values
        rul_values  = engine_data['RUL'].values if has_rul else np.array([])

        if len(values) < window_size:
            continue

        for i in range(0, len(values) - window_size + 1, stride):
            sequences.append(values[i:i + window_size])
            if has_rul:
                targets.append(rul_values[i + window_size - 1])
            engine_ids.append(engine_id)

    return np.array(sequences), np.array(targets), np.array(engine_ids)

# ── Feature Scaling ───────────────────────────────────────────
from sklearn.preprocessing import StandardScaler

scaler       = StandardScaler()
feature_cols = [c for c in df_train.columns if c not in ['engine', 'cycle', 'RUL']]
df_train[feature_cols] = scaler.fit_transform(df_train[feature_cols])
df_test[feature_cols]  = scaler.transform(df_test[feature_cols])

# ── Deep Learning Imports ─────────────────────────────────────
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, regularizers, optimizers
from sklearn.model_selection import GroupKFold
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

np.random.seed(42)
tf.random.set_seed(42)

# ── Configuration — IDENTICAL to original ────────────────────
CONFIG = {
    'WINDOW_SIZE'   : 80,
    'STRIDE'        : 3,
    'LSTM_UNITS'    : [128, 96],
    'DENSE_UNITS'   : 128,
    'DROPOUT_RATE'  : 0.30,
    'L2_REG'        : 0.0005,
    'BATCH_SIZE'    : 64,
    'EPOCHS'        : 250,
    'LEARNING_RATE' : 0.0003,
    'PATIENCE'      : 40,
    'N_SPLITS'      : 5
}

print("\nConfiguration:")
for k, v in CONFIG.items():
    print(f"  {k}: {v}")

# ── Build Sequences ───────────────────────────────────────────
X_train, y_train, train_engine_ids = create_sequences(
    df_train, CONFIG['WINDOW_SIZE'], CONFIG['STRIDE']
)
X_test, _, test_engine_ids = create_sequences(
    df_test, CONFIG['WINDOW_SIZE'], CONFIG['STRIDE']
)

print(f"\nTraining sequences : {X_train.shape}")
print(f"Test sequences     : {X_test.shape}")

# ============================================================
# Custom Layers — UNCHANGED
# ============================================================
class GatingLayer(layers.Layer):
    def __init__(self, num_branches, **kwargs):
        super(GatingLayer, self).__init__(**kwargs)
        self.num_branches = num_branches

    def build(self, input_shape):
        self.gate_weights = self.add_weight(
            shape=(input_shape[0][-1], self.num_branches),
            initializer='glorot_uniform', trainable=True
        )
        self.gate_bias = self.add_weight(
            shape=(self.num_branches,),
            initializer='zeros', trainable=True
        )

    def call(self, inputs):
        input_stats = tf.reduce_mean(inputs[0], axis=1)
        gate_scores = tf.nn.softmax(
            tf.matmul(input_stats, self.gate_weights) + self.gate_bias, axis=-1
        )
        gate_scores = tf.expand_dims(tf.expand_dims(gate_scores, 1), -1)
        stacked     = tf.stack(inputs, axis=2)
        gated       = stacked * gate_scores
        return tf.reduce_sum(gated, axis=2)


class AttentionLayer(layers.Layer):
    """Temporal attention — highlights critical timesteps."""

    def build(self, input_shape):
        self.W = self.add_weight(shape=(input_shape[-1], input_shape[-1]),
                                 initializer="glorot_uniform", trainable=True)
        self.b = self.add_weight(shape=(input_shape[-1],),
                                 initializer="zeros", trainable=True)
        self.u = self.add_weight(shape=(input_shape[-1],),
                                 initializer="glorot_uniform", trainable=True)

    def call(self, x):
        u_t         = tf.tanh(tf.tensordot(x, self.W, axes=1) + self.b)
        attn_scores = tf.nn.softmax(tf.tensordot(u_t, self.u, axes=1), axis=1)
        attn_scores = tf.expand_dims(attn_scores, -1)
        return tf.reduce_sum(x * attn_scores, axis=1)


# ============================================================
# Model Builder — UNCHANGED
# ============================================================
def build_gated_attention_bilstm(input_shape, config):
    inputs = layers.Input(shape=input_shape, name='input')

    branch_lstm = layers.LSTM(
        64, return_sequences=True,
        kernel_regularizer=regularizers.l2(config['L2_REG'])
    )(inputs)
    branch_lstm = layers.LayerNormalization()(branch_lstm)

    branch_gru = layers.GRU(
        64, return_sequences=True,
        kernel_regularizer=regularizers.l2(config['L2_REG'])
    )(inputs)
    branch_gru = layers.LayerNormalization()(branch_gru)

    branch_cnn = layers.Conv1D(64, 5, padding='same', activation='relu',
                               kernel_regularizer=regularizers.l2(config['L2_REG']))(inputs)
    branch_cnn = layers.Conv1D(64, 3, padding='same', activation='relu',
                               kernel_regularizer=regularizers.l2(config['L2_REG']))(branch_cnn)
    branch_cnn = layers.LayerNormalization()(branch_cnn)

    fused = GatingLayer(num_branches=3)([branch_lstm, branch_gru, branch_cnn])
    fused = layers.Dropout(config['DROPOUT_RATE'])(fused)

    x = layers.Bidirectional(
        layers.LSTM(config['LSTM_UNITS'][0], return_sequences=True,
                    kernel_regularizer=regularizers.l2(config['L2_REG'])),
        name='bilstm_1'
    )(fused)
    x = layers.LayerNormalization()(x)
    x = layers.Dropout(config['DROPOUT_RATE'])(x)

    x = layers.Bidirectional(
        layers.LSTM(config['LSTM_UNITS'][1], return_sequences=True,
                    kernel_regularizer=regularizers.l2(config['L2_REG'])),
        name='bilstm_2'
    )(x)
    x = layers.LayerNormalization()(x)
    x = layers.Dropout(config['DROPOUT_RATE'])(x)

    context = AttentionLayer()(x)
    x       = layers.Dense(config['DENSE_UNITS'], activation='relu')(context)
    x       = layers.Dropout(config['DROPOUT_RATE'])(x)
    outputs = layers.Dense(1, activation='linear', name='rul_output')(x)

    model = models.Model(inputs, outputs, name='Gated_Attention_BiLSTM')
    model.compile(
        optimizer=optimizers.Adam(learning_rate=config['LEARNING_RATE']),
        loss=tf.keras.losses.Huber(delta=2.0),
        metrics=['mae', 'mse']
    )
    return model


# ============================================================
# Cross-Validated Training
# Key changes vs original:
#   1. Returns ALL models (not just best) for ensembling
#   2. Best fold picked by MAE (not R²)
#   3. Rebalanced sample weights
# ============================================================
def train_model_with_cv(X_train, y_train, engine_ids, input_shape, config, n_splits=5):
    gkf = GroupKFold(n_splits=n_splits)
    results, models_list = [], []

    for fold, (tr_idx, val_idx) in enumerate(
        gkf.split(X_train, y_train, engine_ids), 1
    ):
        print(f"\n{'='*25} FOLD {fold}/{n_splits} {'='*25}")
        X_tr, X_val = X_train[tr_idx], X_train[val_idx]
        y_tr, y_val = y_train[tr_idx], y_train[val_idx]

        model = build_gated_attention_bilstm(input_shape, config)

        cb = [
            callbacks.ReduceLROnPlateau(
                monitor='val_loss', factor=0.6, patience=12,
                min_lr=5e-7, verbose=1
            ),
            callbacks.EarlyStopping(
                monitor='val_loss', patience=config['PATIENCE'],
                restore_best_weights=True
            ),
            callbacks.ModelCheckpoint(
                f"best_fold_{fold}.h5", save_best_only=True
            )
        ]

        # Rebalanced weights:
        #   - High RUL (>100): reduced from 1.5 → 1.2 to ease overprediction bias
        #   - Low RUL (≤40) : boosted to 1.3 to sharpen near-failure accuracy
        sample_weights = np.ones(len(y_tr))
        sample_weights[y_tr > 100] = 1.2
        sample_weights[y_tr <= 40] = 1.3

        history = model.fit(
            X_tr, y_tr,
            validation_data=(X_val, y_val),
            sample_weight=sample_weights,
            epochs=config['EPOCHS'],
            batch_size=config['BATCH_SIZE'],
            verbose=1,
            callbacks=cb
        )

        val_loss, val_mae, val_mse = model.evaluate(X_val, y_val, verbose=0)
        val_rmse   = np.sqrt(val_mse)
        y_pred_val = model.predict(X_val, verbose=0).flatten()
        val_r2     = r2_score(y_val, y_pred_val)

        results.append({'fold': fold, 'mae': val_mae, 'rmse': val_rmse, 'r2': val_r2})
        models_list.append(model)
        print(f"Fold {fold} → MAE: {val_mae:.4f} | RMSE: {val_rmse:.4f} | R²: {val_r2:.4f}")

    print("\n=== Cross-Validation Summary ===")
    avg_mae  = np.mean([r['mae']  for r in results])
    avg_rmse = np.mean([r['rmse'] for r in results])
    avg_r2   = np.mean([r['r2']   for r in results])
    print(f"Avg MAE: {avg_mae:.4f} | Avg RMSE: {avg_rmse:.4f} | Avg R²: {avg_r2:.4f}")

    # Select best fold by MAE (more stable than R² across folds)
    best_idx = np.argmin([r['mae'] for r in results])
    print(f"\nBest Fold (by MAE): {best_idx + 1}")

    # Also report which fold would have been picked by R²
    r2_best_idx = np.argmax([r['r2'] for r in results])
    print(f"Best Fold (by R²) : {r2_best_idx + 1}  "
          f"[MAE={results[r2_best_idx]['mae']:.4f}, R²={results[r2_best_idx]['r2']:.4f}]")

    return models_list, results, best_idx


# ── Run Training ──────────────────────────────────────────────
input_shape = (X_train.shape[1], X_train.shape[2])

all_models, cv_results, best_fold_idx = train_model_with_cv(
    X_train, y_train, train_engine_ids,
    input_shape, CONFIG, CONFIG['N_SPLITS']
)
best_model = all_models[best_fold_idx]


# ============================================================
# Ensemble Prediction — all 5 fold models averaged
# Closes val→test gap by averaging out fold-specific overfitting
# ============================================================
def ensemble_predict(models, X, batch_size=256):
    preds = np.stack(
        [m.predict(X, verbose=0, batch_size=batch_size).flatten()
         for m in models],
        axis=0
    )
    return preds.mean(axis=0)


# ── Test Predictions: Single Best vs Full Ensemble ────────────
y_single_pred_all = best_model.predict(X_test, verbose=0).flatten()
y_single_pred_all = np.clip(y_single_pred_all, 0, None)

y_ensemble_pred_all = ensemble_predict(all_models, X_test)
y_ensemble_pred_all = np.clip(y_ensemble_pred_all, 0, None)

# ── Aggregate: last window per engine ────────────────────────
unique_engines = sorted(set(test_engine_ids))
y_true, y_pred_single, y_pred_ens = [], [], []

for eng_id in unique_engines:
    mask = test_engine_ids == eng_id
    y_pred_single.append(y_single_pred_all[mask][-1])
    y_pred_ens.append(y_ensemble_pred_all[mask][-1])
    y_true.append(df_test_RUL.iloc[int(eng_id) - 1]['RUL'])

y_true        = np.array(y_true)
y_pred_single = np.array(y_pred_single)
y_pred_ens    = np.array(y_pred_ens)

# ── Report Both ───────────────────────────────────────────────
print("\n" + "=" * 55)
print("  FINAL TEST RESULTS")
print("=" * 55)
for label, y_pred in [
    ("Single best model", y_pred_single),
    ("Full ensemble     ", y_pred_ens)
]:
    mae  = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    r2   = r2_score(y_true, y_pred)
    print(f"  {label} → MAE={mae:.4f}  RMSE={rmse:.4f}  R²={r2:.4f}")

# Auto-select best
r2_single = r2_score(y_true, y_pred_single)
r2_ens    = r2_score(y_true, y_pred_ens)

if r2_ens >= r2_single:
    y_pred_final = y_pred_ens
    print("\n  → Using full ensemble predictions")
else:
    y_pred_final = y_pred_single
    print("\n  → Using single best model predictions (ensemble did not help this run)")

final_mae  = mean_absolute_error(y_true, y_pred_final)
final_rmse = np.sqrt(mean_squared_error(y_true, y_pred_final))
final_r2   = r2_score(y_true, y_pred_final)

print(f"\n✅ Final: MAE={final_mae:.4f}  RMSE={final_rmse:.4f}  R²={final_r2:.4f}")

if final_r2 >= 0.80:
    print("🏆 TARGET ACHIEVED: Test R² ≥ 0.80!")
elif final_r2 >= 0.78:
    print("📈 Very close — within 2% of target.")


# ── Deeper Diagnosis ──────────────────────────────────────────
print("\n=== MAE by True RUL Bucket ===")
buckets = [(0, 20), (20, 40), (40, 60), (60, 80), (80, 110), (110, 200)]
for lo, hi in buckets:
    mask = (y_true >= lo) & (y_true < hi)
    if mask.sum() > 0:
        mae_b  = np.abs(y_pred_final - y_true)[mask].mean()
        bias_b = (y_pred_final - y_true)[mask].mean()
        print(f"  RUL {lo:3d}–{hi:3d}: n={mask.sum():3d} | "
              f"MAE={mae_b:.2f} | Bias={bias_b:+.2f}")

print(f"\n=== Prediction Bias ===")
print(f"  Mean error (pred − true): {(y_pred_final - y_true).mean():+.4f}")
print(f"  Engines overpredicted   : {(y_pred_final > y_true).sum()}")
print(f"  Engines underpredicted  : {(y_pred_final < y_true).sum()}")

print(f"\n=== True RUL Distribution ===")
print(f"  True RULs > 110 : {(y_true > 110).sum()} engines")
print(f"  True RULs > 125 : {(y_true > 125).sum()} engines")
print(f"  Max true RUL    : {y_true.max():.1f}")
print(f"  Mean true RUL   : {y_true.mean():.1f}")


# ── Visualisations ────────────────────────────────────────────

# 1. True vs Predicted sorted by true RUL
sorted_idx = np.argsort(y_true)
plt.figure(figsize=(14, 4))
plt.plot(y_true[sorted_idx],       label='True RUL',
         marker='o', ms=3, color='steelblue')
plt.plot(y_pred_final[sorted_idx], label='Predicted RUL',
         marker='x', ms=3, color='tomato')
plt.xlabel('Engine (sorted by True RUL)')
plt.ylabel('RUL')
plt.title('True vs Predicted RUL — sorted by True RUL')
plt.legend()
plt.tight_layout()
plt.show()

# 2. Scatter: Predicted vs True
plt.figure(figsize=(6, 6))
plt.scatter(y_true, y_pred_final, alpha=0.5, s=15, color='steelblue')
mn = min(y_true.min(), y_pred_final.min())
mx = max(y_true.max(), y_pred_final.max())
plt.plot([mn, mx], [mn, mx], 'r--', label='Perfect prediction')
plt.xlabel('True RUL')
plt.ylabel('Predicted RUL')
plt.title(f'Predicted vs True RUL  (R²={final_r2:.3f})')
plt.legend()
plt.tight_layout()
plt.show()

# 3. Residual distribution
residuals = y_pred_final - y_true
plt.figure(figsize=(8, 4))
plt.hist(residuals, bins=30, color='steelblue', edgecolor='white')
plt.axvline(0, color='red', linestyle='--', label='Zero bias')
plt.axvline(residuals.mean(), color='orange', linestyle='--',
            label=f'Mean bias: {residuals.mean():+.2f}')
plt.xlabel('Prediction Error (pred − true)')
plt.ylabel('Count')
plt.title('Residual Distribution')
plt.legend()
plt.tight_layout()
plt.show()

# 4. CV fold performance
fold_labels = [f"Fold {r['fold']}" for r in cv_results]
fold_maes   = [r['mae'] for r in cv_results]
fold_r2s    = [r['r2']  for r in cv_results]

fig, axes = plt.subplots(1, 2, figsize=(12, 4))
axes[0].bar(fold_labels, fold_maes, color='steelblue')
axes[0].set_title('Validation MAE per Fold')
axes[0].set_ylabel('MAE')
axes[1].bar(fold_labels, fold_r2s, color='tomato')
axes[1].set_title('Validation R² per Fold')
axes[1].set_ylabel('R²')
axes[1].axhline(0.80, color='green', linestyle='--', label='Target R²=0.80')
axes[1].legend()
plt.tight_layout()
plt.show()

# 5. Single best vs ensemble comparison (per engine)
plt.figure(figsize=(14, 4))
plt.plot(y_true[sorted_idx],         label='True RUL',      color='steelblue', lw=1.5)
plt.plot(y_pred_single[sorted_idx],  label='Single model',  color='orange',    lw=1, alpha=0.7)
plt.plot(y_pred_ens[sorted_idx],     label='Ensemble',       color='tomato',    lw=1.5)
plt.xlabel('Engine (sorted by True RUL)')
plt.ylabel('RUL')
plt.title('Single Model vs Ensemble vs True RUL')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Configuration:
#   WINDOW_SIZE: 80
#   STRIDE: 3
#   LSTM_UNITS: [128, 96]
#   DENSE_UNITS: 128
#   DROPOUT_RATE: 0.3
#   L2_REG: 0.0005
#   BATCH_SIZE: 64
#   EPOCHS: 250
#   LEARNING_RATE: 0.0003
#   PATIENCE: 40
#   N_SPLITS: 5
#
# Training sequences : (13939, 80, 24)
# Test sequences     : (7704, 80, 24)
#
# ========================= FOLD 1/5 =========================
# Epoch 1/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 153.7234 - mae: 66.8263 - mse: 6751.7456
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 20s 49ms/step - loss: 153.5948 - mae: 66.7667 - mse: 6740.9106 - val_loss: 91.2139 - val_mae: 46.3501 - val_mse: 3015.3022 - learning_rate: 3.0000e-04
# Epoch 2/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 96.2249 - mae: 41.0146 - mse: 2434.6191
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 16s 45ms/step - loss: 96.1268 - mae: 40.9769 - mse: 2431.4292 - val_loss: 47.6132 - val_mae: 24.5334 - val_mse: 1064.5762 - learning_rate: 3.0000e-04
# Epoch 3/250
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 51.6508 - mae: 23.4285 - mse: 979.2139
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - loss: 51.6284 - mae: 23.4189 - mse: 978.6072 - val_loss: 43.7910 - val_mae: 22.6182 - val_mse: 956.1944 - learning_rate: 3.0000e-04
# Epoch 4/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 45.0118 - mae: 20.5700 - mse: 779.3246
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 45.0032 - mae: 20.5662 - mse: 779.1207 - val_loss: 37.1833 - val_mae: 19.3169 - val_mse: 677.6068 - learning_rate: 3.0000e-04
# Epoch 5/250
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 39.8677 - mae: 18.2992 - mse: 644.6913
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 41ms/step - loss: 39.8606 - mae: 18.2960 - mse: 644.5236 - val_loss: 33.6500 - val_mae: 17.5396 - val_mse: 596.9419 - learning_rate: 3.0000e-04
# Epoch 6/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - loss: 37.1162 - mae: 17.0835 - mse: 572.1161 - val_loss: 34.9394 - val_mae: 18.1888 - val_mse: 628.1461 - learning_rate: 3.0000e-04
# Epoch 7/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - loss: 36.3952 - mae: 16.7696 - mse: 559.6030 - val_loss: 35.2084 - val_mae: 18.3200 - val_mse: 640.0400 - learning_rate: 3.0000e-04
# Epoch 8/250
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 34.8014 - mae: 16.0488 - mse: 513.6951
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 10s 42ms/step - loss: 34.7968 - mae: 16.0468 - mse: 513.6791 - val_loss: 32.4423 - val_mae: 16.9366 - val_mse: 564.5372 - learning_rate: 3.0000e-04
# Epoch 9/250
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 33.4694 - mae: 15.4558 - mse: 483.7468
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 33.4621 - mae: 15.4525 - mse: 483.6656 - val_loss: 31.8162 - val_mae: 16.6179 - val_mse: 535.9890 - learning_rate: 3.0000e-04
# Epoch 10/250
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 32.3846 - mae: 14.9468 - mse: 457.8706
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - loss: 32.3779 - mae: 14.9438 - mse: 457.7930 - val_loss: 31.1369 - val_mae: 16.2808 - val_mse: 533.5235 - learning_rate: 3.0000e-04
# Epoch 11/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 9s 52ms/step - loss: 31.9053 - mae: 14.7374 - mse: 447.3434 - val_loss: 31.8945 - val_mae: 16.6515 - val_mse: 560.1590 - learning_rate: 3.0000e-04
# Epoch 12/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 9s 46ms/step - loss: 30.7791 - mae: 14.2270 - mse: 424.8844 - val_loss: 34.0736 - val_mae: 17.7485 - val_mse: 622.1360 - learning_rate: 3.0000e-04
# Epoch 13/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 41ms/step - loss: 29.4831 - mae: 13.6498 - mse: 398.6101 - val_loss: 33.1115 - val_mae: 17.2672 - val_mse: 595.1938 - learning_rate: 3.0000e-04
# Epoch 14/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - loss: 29.1748 - mae: 13.5073 - mse: 383.6234 - val_loss: 31.4759 - val_mae: 16.4392 - val_mse: 569.1543 - learning_rate: 3.0000e-04
# Epoch 15/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - loss: 28.2047 - mae: 13.0572 - mse: 363.3498 - val_loss: 32.5454 - val_mae: 16.9782 - val_mse: 563.8880 - learning_rate: 3.0000e-04
# Epoch 16/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - loss: 27.2833 - mae: 12.6336 - mse: 344.2120 - val_loss: 32.9368 - val_mae: 17.1759 - val_mse: 596.2099 - learning_rate: 3.0000e-04
# Epoch 17/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - loss: 25.7391 - mae: 11.9646 - mse: 316.4539 - val_loss: 35.2331 - val_mae: 18.3217 - val_mse: 654.3854 - learning_rate: 3.0000e-04
# Epoch 18/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 40ms/step - loss: 25.6373 - mae: 11.9094 - mse: 309.0293 - val_loss: 35.1857 - val_mae: 18.3010 - val_mse: 659.4357 - learning_rate: 3.0000e-04
# Epoch 19/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - loss: 24.0890 - mae: 11.2364 - mse: 282.6468 - val_loss: 32.8457 - val_mae: 17.1246 - val_mse: 601.3163 - learning_rate: 3.0000e-04
# Epoch 20/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 40ms/step - loss: 24.5072 - mae: 11.3871 - mse: 283.0175 - val_loss: 35.9621 - val_mae: 18.6818 - val_mse: 712.2480 - learning_rate: 3.0000e-04
# Epoch 21/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - loss: 23.7515 - mae: 11.0514 - mse: 267.2392 - val_loss: 37.3324 - val_mae: 19.3678 - val_mse: 760.1515 - learning_rate: 3.0000e-04
# Epoch 22/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 23.2264 - mae: 10.8494 - mse: 252.8792
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.00018000000854954124.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - loss: 23.2226 - mae: 10.8477 - mse: 252.8400 - val_loss: 38.2307 - val_mae: 19.8123 - val_mse: 793.6177 - learning_rate: 3.0000e-04
# Epoch 23/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - loss: 20.9990 - mae: 9.8427 - mse: 219.0672 - val_loss: 35.2797 - val_mae: 18.3354 - val_mse: 691.3092 - learning_rate: 1.8000e-04
# Epoch 24/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - loss: 20.4960 - mae: 9.6126 - mse: 207.5111 - val_loss: 34.9698 - val_mae: 18.1806 - val_mse: 665.8286 - learning_rate: 1.8000e-04
# Epoch 25/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 10s 43ms/step - loss: 19.0795 - mae: 8.9920 - mse: 185.9255 - val_loss: 36.7139 - val_mae: 19.0528 - val_mse: 750.2967 - learning_rate: 1.8000e-04
# Epoch 26/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - loss: 19.5359 - mae: 9.2070 - mse: 192.1613 - val_loss: 34.3651 - val_mae: 17.8801 - val_mse: 651.0958 - learning_rate: 1.8000e-04
# Epoch 27/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - loss: 19.1088 - mae: 9.0068 - mse: 185.4260 - val_loss: 34.9315 - val_mae: 18.1618 - val_mse: 687.0459 - learning_rate: 1.8000e-04
# Epoch 28/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 41ms/step - loss: 18.4197 - mae: 8.7186 - mse: 172.8979 - val_loss: 39.4503 - val_mae: 20.4178 - val_mse: 831.4167 - learning_rate: 1.8000e-04
# Epoch 29/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 18.5869 - mae: 8.7817 - mse: 172.0620 - val_loss: 35.5510 - val_mae: 18.4671 - val_mse: 697.0183 - learning_rate: 1.8000e-04
# Epoch 30/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 41ms/step - loss: 18.0092 - mae: 8.5303 - mse: 162.7322 - val_loss: 36.2182 - val_mae: 18.8050 - val_mse: 724.4797 - learning_rate: 1.8000e-04
# Epoch 31/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - loss: 17.2487 - mae: 8.1880 - mse: 151.6470 - val_loss: 36.6203 - val_mae: 19.0109 - val_mse: 736.2739 - learning_rate: 1.8000e-04
# Epoch 32/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - loss: 17.4813 - mae: 8.2955 - mse: 151.9530 - val_loss: 37.7816 - val_mae: 19.5872 - val_mse: 759.6068 - learning_rate: 1.8000e-04
# Epoch 33/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - loss: 17.2970 - mae: 8.2117 - mse: 150.4248 - val_loss: 35.7640 - val_mae: 18.5799 - val_mse: 705.5966 - learning_rate: 1.8000e-04
# Epoch 34/250
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 16.4150 - mae: 7.8259 - mse: 139.4761
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.00010800000163726508.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 16.4184 - mae: 7.8274 - mse: 139.4843 - val_loss: 36.8081 - val_mae: 19.0957 - val_mse: 737.7198 - learning_rate: 1.8000e-04
# Epoch 35/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 15.9090 - mae: 7.5999 - mse: 128.5215 - val_loss: 34.8946 - val_mae: 18.1438 - val_mse: 663.6617 - learning_rate: 1.0800e-04
# Epoch 36/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 16.0788 - mae: 7.6553 - mse: 132.9501 - val_loss: 36.9137 - val_mae: 19.1565 - val_mse: 729.3560 - learning_rate: 1.0800e-04
# Epoch 37/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 16.3196 - mae: 7.7760 - mse: 135.1121 - val_loss: 36.7820 - val_mae: 19.0849 - val_mse: 740.9094 - learning_rate: 1.0800e-04
# Epoch 38/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - loss: 15.5026 - mae: 7.4087 - mse: 125.1667 - val_loss: 36.7202 - val_mae: 19.0568 - val_mse: 739.9902 - learning_rate: 1.0800e-04
# Epoch 39/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - loss: 15.5845 - mae: 7.4527 - mse: 122.3847 - val_loss: 37.6147 - val_mae: 19.4988 - val_mse: 783.8997 - learning_rate: 1.0800e-04
# Epoch 40/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 15.5604 - mae: 7.4449 - mse: 125.4893 - val_loss: 36.2326 - val_mae: 18.8136 - val_mse: 718.1136 - learning_rate: 1.0800e-04
# Epoch 41/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - loss: 15.2980 - mae: 7.3213 - mse: 118.4539 - val_loss: 35.1812 - val_mae: 18.2819 - val_mse: 691.7903 - learning_rate: 1.0800e-04
# Epoch 42/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - loss: 15.3152 - mae: 7.3179 - mse: 119.4019 - val_loss: 35.5170 - val_mae: 18.4540 - val_mse: 699.5668 - learning_rate: 1.0800e-04
# Epoch 43/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - loss: 15.2104 - mae: 7.2983 - mse: 118.3943 - val_loss: 37.3501 - val_mae: 19.3680 - val_mse: 754.6332 - learning_rate: 1.0800e-04
# Epoch 44/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 15.1268 - mae: 7.2406 - mse: 114.9163 - val_loss: 35.8345 - val_mae: 18.6130 - val_mse: 700.2848 - learning_rate: 1.0800e-04
# Epoch 45/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 41ms/step - loss: 14.8371 - mae: 7.1222 - mse: 110.1246 - val_loss: 36.5012 - val_mae: 18.9456 - val_mse: 732.4962 - learning_rate: 1.0800e-04
# Epoch 46/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 15.1474 - mae: 7.2569 - mse: 114.0387
# Epoch 46: ReduceLROnPlateau reducing learning rate to 6.480000010924413e-05.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 15.1463 - mae: 7.2565 - mse: 114.0127 - val_loss: 35.7508 - val_mae: 18.5692 - val_mse: 711.8910 - learning_rate: 1.0800e-04
# Epoch 47/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - loss: 14.7006 - mae: 7.0600 - mse: 105.0597 - val_loss: 36.1918 - val_mae: 18.7941 - val_mse: 711.4912 - learning_rate: 6.4800e-05
# Epoch 48/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - loss: 14.3856 - mae: 6.9234 - mse: 101.9191 - val_loss: 35.9648 - val_mae: 18.6784 - val_mse: 715.7271 - learning_rate: 6.4800e-05
# Epoch 49/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 13.9899 - mae: 6.7466 - mse: 97.1207 - val_loss: 35.6219 - val_mae: 18.5045 - val_mse: 716.0182 - learning_rate: 6.4800e-05
# Epoch 50/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 10s 43ms/step - loss: 14.2571 - mae: 6.8583 - mse: 102.0632 - val_loss: 36.0184 - val_mae: 18.7069 - val_mse: 723.2156 - learning_rate: 6.4800e-05
# Fold 1 → MAE: 16.2808 | RMSE: 23.0981 | R²: 0.8195
#
# ========================= FOLD 2/5 =========================
# Epoch 1/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 149.3728 - mae: 65.0063 - mse: 6522.1270
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 55ms/step - loss: 149.2221 - mae: 64.9387 - mse: 6510.7573 - val_loss: 59.4090 - val_mae: 30.4398 - val_mse: 1440.8199 - learning_rate: 3.0000e-04
# Epoch 2/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 65.9450 - mae: 29.4682 - mse: 1473.7803
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 48ms/step - loss: 65.9092 - mae: 29.4535 - mse: 1472.5717 - val_loss: 39.7004 - val_mae: 20.5730 - val_mse: 766.9771 - learning_rate: 3.0000e-04
# Epoch 3/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 51.3333 - mae: 23.3770 - mse: 998.9831
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 51.3199 - mae: 23.3711 - mse: 998.5575 - val_loss: 36.3739 - val_mae: 18.9011 - val_mse: 681.5066 - learning_rate: 3.0000e-04
# Epoch 4/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 45.3396 - mae: 20.6385 - mse: 808.2395
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 45.3308 - mae: 20.6349 - mse: 808.0082 - val_loss: 33.5891 - val_mae: 17.5077 - val_mse: 581.7768 - learning_rate: 3.0000e-04
# Epoch 5/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 40.6479 - mae: 18.5919 - mse: 669.0096
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - loss: 40.6432 - mae: 18.5900 - mse: 668.9266 - val_loss: 29.8364 - val_mae: 15.6244 - val_mse: 476.0844 - learning_rate: 3.0000e-04
# Epoch 6/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - loss: 37.3145 - mae: 17.1213 - mse: 587.8105 - val_loss: 30.4594 - val_mae: 15.9327 - val_mse: 475.0260 - learning_rate: 3.0000e-04
# Epoch 7/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - loss: 36.3311 - mae: 16.6868 - mse: 561.7570 - val_loss: 31.4825 - val_mae: 16.4454 - val_mse: 514.3770 - learning_rate: 3.0000e-04
# Epoch 8/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 10s 42ms/step - loss: 35.5263 - mae: 16.3943 - mse: 544.4576 - val_loss: 30.4205 - val_mae: 15.9167 - val_mse: 492.8172 - learning_rate: 3.0000e-04
# Epoch 9/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 34.1792 - mae: 15.7473 - mse: 501.2443 - val_loss: 33.7551 - val_mae: 17.5835 - val_mse: 587.0630 - learning_rate: 3.0000e-04
# Epoch 10/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - loss: 33.6046 - mae: 15.4883 - mse: 503.2782 - val_loss: 31.4320 - val_mae: 16.4208 - val_mse: 526.3177 - learning_rate: 3.0000e-04
# Epoch 11/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 31.4132 - mae: 14.5259 - mse: 445.0178 - val_loss: 33.0012 - val_mae: 17.2013 - val_mse: 550.4019 - learning_rate: 3.0000e-04
# Epoch 12/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 30.3661 - mae: 14.0492 - mse: 424.5830 - val_loss: 32.7900 - val_mae: 17.1027 - val_mse: 548.0573 - learning_rate: 3.0000e-04
# Epoch 13/250
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 29.3636 - mae: 13.6047 - mse: 401.2308
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - loss: 29.3569 - mae: 13.6017 - mse: 401.0877 - val_loss: 28.8988 - val_mae: 15.1488 - val_mse: 437.4437 - learning_rate: 3.0000e-04
# Epoch 14/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - loss: 28.3611 - mae: 13.1480 - mse: 372.0718 - val_loss: 31.2199 - val_mae: 16.3036 - val_mse: 499.5425 - learning_rate: 3.0000e-04
# Epoch 15/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - loss: 27.7583 - mae: 12.8793 - mse: 362.4962 - val_loss: 30.6510 - val_mae: 16.0245 - val_mse: 470.7191 - learning_rate: 3.0000e-04
# Epoch 16/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - loss: 26.4843 - mae: 12.3108 - mse: 330.0119 - val_loss: 31.3117 - val_mae: 16.3480 - val_mse: 510.2885 - learning_rate: 3.0000e-04
# Epoch 17/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - loss: 25.0256 - mae: 11.6606 - mse: 304.1889 - val_loss: 30.5832 - val_mae: 15.9915 - val_mse: 467.2037 - learning_rate: 3.0000e-04
# Epoch 18/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 41ms/step - loss: 24.5679 - mae: 11.4623 - mse: 291.9226 - val_loss: 31.0209 - val_mae: 16.2058 - val_mse: 483.5229 - learning_rate: 3.0000e-04
# Epoch 19/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - loss: 23.2754 - mae: 10.8880 - mse: 258.5247 - val_loss: 33.0671 - val_mae: 17.2321 - val_mse: 543.0887 - learning_rate: 3.0000e-04
# Epoch 20/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 49ms/step - loss: 22.3824 - mae: 10.4676 - mse: 240.0092 - val_loss: 32.0117 - val_mae: 16.6977 - val_mse: 517.4833 - learning_rate: 3.0000e-04
# Epoch 21/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 22.2182 - mae: 10.4018 - mse: 239.2662 - val_loss: 34.0213 - val_mae: 17.7072 - val_mse: 568.9669 - learning_rate: 3.0000e-04
# Epoch 22/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 21.4364 - mae: 10.0350 - mse: 224.0799 - val_loss: 33.7649 - val_mae: 17.5728 - val_mse: 544.9534 - learning_rate: 3.0000e-04
# Epoch 23/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 20.1840 - mae: 9.4947 - mse: 200.3004 - val_loss: 34.4754 - val_mae: 17.9360 - val_mse: 563.9238 - learning_rate: 3.0000e-04
# Epoch 24/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 20.1915 - mae: 9.4975 - mse: 191.9822 - val_loss: 33.4129 - val_mae: 17.4005 - val_mse: 544.6113 - learning_rate: 3.0000e-04
# Epoch 25/250
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 19.7938 - mae: 9.3134 - mse: 190.7535
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.00018000000854954124.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 9s 49ms/step - loss: 19.7931 - mae: 9.3131 - mse: 190.7131 - val_loss: 33.6334 - val_mae: 17.5130 - val_mse: 534.1078 - learning_rate: 3.0000e-04
# Epoch 26/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 18.5690 - mae: 8.7816 - mse: 164.3406 - val_loss: 32.8209 - val_mae: 17.1030 - val_mse: 520.3908 - learning_rate: 1.8000e-04
# Epoch 27/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 17.3584 - mae: 8.2336 - mse: 149.5423 - val_loss: 33.0242 - val_mae: 17.1987 - val_mse: 546.2215 - learning_rate: 1.8000e-04
# Epoch 28/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 17.1190 - mae: 8.1226 - mse: 142.9307 - val_loss: 33.1099 - val_mae: 17.2458 - val_mse: 535.6372 - learning_rate: 1.8000e-04
# Epoch 29/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 16.8831 - mae: 8.0225 - mse: 139.4608 - val_loss: 33.6882 - val_mae: 17.5340 - val_mse: 550.0665 - learning_rate: 1.8000e-04
# Epoch 30/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - loss: 16.9317 - mae: 8.0479 - mse: 137.6120 - val_loss: 34.5930 - val_mae: 17.9838 - val_mse: 571.9067 - learning_rate: 1.8000e-04
# Epoch 31/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - loss: 16.5547 - mae: 7.8930 - mse: 131.9598 - val_loss: 34.7176 - val_mae: 18.0502 - val_mse: 588.3602 - learning_rate: 1.8000e-04
# Epoch 32/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 16.5846 - mae: 7.8883 - mse: 131.2528 - val_loss: 34.2700 - val_mae: 17.8164 - val_mse: 598.9099 - learning_rate: 1.8000e-04
# Epoch 33/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 16.6021 - mae: 7.9032 - mse: 128.4320 - val_loss: 33.9176 - val_mae: 17.6477 - val_mse: 541.9114 - learning_rate: 1.8000e-04
# Epoch 34/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 16.0113 - mae: 7.6305 - mse: 119.8692 - val_loss: 33.6984 - val_mae: 17.5433 - val_mse: 547.2142 - learning_rate: 1.8000e-04
# Epoch 35/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - loss: 15.7031 - mae: 7.5056 - mse: 116.9414 - val_loss: 35.0726 - val_mae: 18.2246 - val_mse: 585.0388 - learning_rate: 1.8000e-04
# Epoch 36/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - loss: 15.8699 - mae: 7.5724 - mse: 119.5787 - val_loss: 34.7467 - val_mae: 18.0598 - val_mse: 580.7021 - learning_rate: 1.8000e-04
# Epoch 37/250
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 15.6209 - mae: 7.4706 - mse: 115.1410
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.00010800000163726508.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 15.6223 - mae: 7.4712 - mse: 115.1491 - val_loss: 36.5811 - val_mae: 18.9834 - val_mse: 639.3684 - learning_rate: 1.8000e-04
# Epoch 38/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 10s 43ms/step - loss: 15.1684 - mae: 7.2548 - mse: 107.4821 - val_loss: 34.8933 - val_mae: 18.1351 - val_mse: 586.8369 - learning_rate: 1.0800e-04
# Epoch 39/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - loss: 14.7615 - mae: 7.0946 - mse: 100.7055 - val_loss: 34.8349 - val_mae: 18.1017 - val_mse: 593.6382 - learning_rate: 1.0800e-04
# Epoch 40/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 14.4667 - mae: 6.9605 - mse: 98.5624 - val_loss: 34.7487 - val_mae: 18.0623 - val_mse: 568.6045 - learning_rate: 1.0800e-04
# Epoch 41/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 10s 42ms/step - loss: 14.3743 - mae: 6.9105 - mse: 96.1418 - val_loss: 34.8861 - val_mae: 18.1354 - val_mse: 572.3935 - learning_rate: 1.0800e-04
# Epoch 42/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 14.3808 - mae: 6.9189 - mse: 97.7347 - val_loss: 34.5407 - val_mae: 17.9639 - val_mse: 574.4424 - learning_rate: 1.0800e-04
# Epoch 43/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - loss: 14.4491 - mae: 6.9419 - mse: 99.2168 - val_loss: 35.3549 - val_mae: 18.3704 - val_mse: 619.5338 - learning_rate: 1.0800e-04
# Epoch 44/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - loss: 14.0764 - mae: 6.7930 - mse: 90.0491 - val_loss: 35.2652 - val_mae: 18.3218 - val_mse: 620.6039 - learning_rate: 1.0800e-04
# Epoch 45/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 14.0717 - mae: 6.7779 - mse: 92.3611 - val_loss: 35.0773 - val_mae: 18.2260 - val_mse: 585.8985 - learning_rate: 1.0800e-04
# Epoch 46/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 14.4377 - mae: 6.9411 - mse: 100.6042 - val_loss: 35.0946 - val_mae: 18.2374 - val_mse: 574.1569 - learning_rate: 1.0800e-04
# Epoch 47/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 14.2084 - mae: 6.8417 - mse: 94.2331 - val_loss: 34.8907 - val_mae: 18.1359 - val_mse: 598.2830 - learning_rate: 1.0800e-04
# Epoch 48/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 14.2480 - mae: 6.8673 - mse: 93.9521 - val_loss: 34.9427 - val_mae: 18.1607 - val_mse: 589.9008 - learning_rate: 1.0800e-04
# Epoch 49/250
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 14.0381 - mae: 6.7584 - mse: 93.7565
# Epoch 49: ReduceLROnPlateau reducing learning rate to 6.480000010924413e-05.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - loss: 14.0389 - mae: 6.7588 - mse: 93.7573 - val_loss: 35.0144 - val_mae: 18.1970 - val_mse: 594.7783 - learning_rate: 1.0800e-04
# Epoch 50/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 13.8326 - mae: 6.6723 - mse: 93.0739 - val_loss: 34.9018 - val_mae: 18.1384 - val_mse: 602.8992 - learning_rate: 6.4800e-05
# Epoch 51/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 13.6245 - mae: 6.5845 - mse: 88.2274 - val_loss: 35.2525 - val_mae: 18.3169 - val_mse: 600.2689 - learning_rate: 6.4800e-05
# Epoch 52/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 13.3943 - mae: 6.4787 - mse: 83.0395 - val_loss: 35.4064 - val_mae: 18.3898 - val_mse: 615.3981 - learning_rate: 6.4800e-05
# Epoch 53/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - loss: 13.4871 - mae: 6.5160 - mse: 86.8467 - val_loss: 34.8154 - val_mae: 18.0948 - val_mse: 584.9359 - learning_rate: 6.4800e-05
# Fold 2 → MAE: 15.1488 | RMSE: 20.9152 | R²: 0.8449
#
# ========================= FOLD 3/5 =========================
# Epoch 1/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 153.4452 - mae: 66.7605 - mse: 6783.2856
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 17s 50ms/step - loss: 153.3289 - mae: 66.7060 - mse: 6773.2920 - val_loss: 90.6390 - val_mae: 46.0623 - val_mse: 2932.7283 - learning_rate: 3.0000e-04
# Epoch 2/250
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 109.0581 - mae: 46.0214 - mse: 2919.8142
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 109.0338 - mae: 46.0123 - mse: 2918.9465 - val_loss: 74.7668 - val_mae: 38.1271 - val_mse: 2365.5991 - learning_rate: 3.0000e-04
# Epoch 3/250
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 72.0397 - mae: 31.9119 - mse: 1687.9873
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 71.9456 - mae: 31.8734 - mse: 1684.7198 - val_loss: 51.0389 - val_mae: 26.2548 - val_mse: 1118.1667 - learning_rate: 3.0000e-04
# Epoch 4/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 53.2521 - mae: 24.1665 - mse: 1057.7738
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 48ms/step - loss: 53.2467 - mae: 24.1641 - mse: 1057.5931 - val_loss: 45.0459 - val_mae: 23.2566 - val_mse: 914.7378 - learning_rate: 3.0000e-04
# Epoch 5/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 45.5509 - mae: 20.8204 - mse: 829.2927
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - loss: 45.5475 - mae: 20.8188 - mse: 829.1089 - val_loss: 36.8218 - val_mae: 19.1345 - val_mse: 690.7590 - learning_rate: 3.0000e-04
# Epoch 6/250
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 42.0418 - mae: 19.2472 - mse: 715.8414
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 42.0376 - mae: 19.2452 - mse: 715.6960 - val_loss: 33.8082 - val_mae: 17.6174 - val_mse: 604.1481 - learning_rate: 3.0000e-04
# Epoch 7/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 39.9461 - mae: 18.3047 - mse: 651.5007 - val_loss: 37.7975 - val_mae: 19.6209 - val_mse: 690.6037 - learning_rate: 3.0000e-04
# Epoch 8/250
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 38.1232 - mae: 17.5101 - mse: 613.7115
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 38.1165 - mae: 17.5072 - mse: 613.5587 - val_loss: 31.7418 - val_mae: 16.5830 - val_mse: 562.0067 - learning_rate: 3.0000e-04
# Epoch 9/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 36.0643 - mae: 16.6037 - mse: 556.6260 - val_loss: 36.3886 - val_mae: 18.9131 - val_mse: 680.6534 - learning_rate: 3.0000e-04
# Epoch 10/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - loss: 35.6502 - mae: 16.3896 - mse: 552.4387 - val_loss: 35.4794 - val_mae: 18.4618 - val_mse: 643.2967 - learning_rate: 3.0000e-04
# Epoch 11/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - loss: 34.6379 - mae: 15.9659 - mse: 525.0204 - val_loss: 36.0060 - val_mae: 18.7204 - val_mse: 690.8980 - learning_rate: 3.0000e-04
# Epoch 12/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 34.0453 - mae: 15.6731 - mse: 514.5789 - val_loss: 35.3024 - val_mae: 18.3671 - val_mse: 628.0035 - learning_rate: 3.0000e-04
# Epoch 13/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 32.9949 - mae: 15.2509 - mse: 486.4259 - val_loss: 32.8532 - val_mae: 17.1428 - val_mse: 570.0867 - learning_rate: 3.0000e-04
# Epoch 14/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - loss: 32.3796 - mae: 14.9595 - mse: 459.4076 - val_loss: 32.1711 - val_mae: 16.8029 - val_mse: 558.4033 - learning_rate: 3.0000e-04
# Epoch 15/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - loss: 31.8014 - mae: 14.6992 - mse: 455.7696 - val_loss: 35.5632 - val_mae: 18.4972 - val_mse: 641.1279 - learning_rate: 3.0000e-04
# Epoch 16/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 29.5032 - mae: 13.6750 - mse: 405.5761 - val_loss: 34.3315 - val_mae: 17.8810 - val_mse: 604.5403 - learning_rate: 3.0000e-04
# Epoch 17/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - loss: 29.0775 - mae: 13.4991 - mse: 404.1783 - val_loss: 36.1868 - val_mae: 18.8132 - val_mse: 658.3872 - learning_rate: 3.0000e-04
# Epoch 18/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 10s 47ms/step - loss: 29.3855 - mae: 13.6021 - mse: 389.0416 - val_loss: 33.9930 - val_mae: 17.7071 - val_mse: 622.2667 - learning_rate: 3.0000e-04
# Epoch 19/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 27.6657 - mae: 12.8388 - mse: 357.1956 - val_loss: 36.6675 - val_mae: 19.0455 - val_mse: 670.8419 - learning_rate: 3.0000e-04
# Epoch 20/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 26.8845 - mae: 12.4997 - mse: 338.3101
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.00018000000854954124.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - loss: 26.8831 - mae: 12.4991 - mse: 338.3137 - val_loss: 37.4368 - val_mae: 19.4273 - val_mse: 715.4506 - learning_rate: 3.0000e-04
# Epoch 21/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 25.2626 - mae: 11.7629 - mse: 315.0361 - val_loss: 34.7014 - val_mae: 18.0642 - val_mse: 627.9133 - learning_rate: 1.8000e-04
# Epoch 22/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 24.4736 - mae: 11.4027 - mse: 295.5942 - val_loss: 35.3103 - val_mae: 18.3656 - val_mse: 644.0634 - learning_rate: 1.8000e-04
# Epoch 23/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - loss: 23.5243 - mae: 10.9913 - mse: 268.2868 - val_loss: 37.3448 - val_mae: 19.3884 - val_mse: 695.3346 - learning_rate: 1.8000e-04
# Epoch 24/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 41ms/step - loss: 23.7966 - mae: 11.0990 - mse: 276.7192 - val_loss: 34.6533 - val_mae: 18.0411 - val_mse: 609.9174 - learning_rate: 1.8000e-04
# Epoch 25/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - loss: 23.0436 - mae: 10.7611 - mse: 262.6660 - val_loss: 33.6682 - val_mae: 17.5496 - val_mse: 583.2537 - learning_rate: 1.8000e-04
# Epoch 26/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - loss: 22.4148 - mae: 10.4939 - mse: 253.1483 - val_loss: 35.3545 - val_mae: 18.3916 - val_mse: 633.4205 - learning_rate: 1.8000e-04
# Epoch 27/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - loss: 22.1949 - mae: 10.3907 - mse: 245.7478 - val_loss: 37.3008 - val_mae: 19.3688 - val_mse: 689.7740 - learning_rate: 1.8000e-04
# Epoch 28/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 21.9809 - mae: 10.2927 - mse: 238.7314 - val_loss: 36.6925 - val_mae: 19.0575 - val_mse: 685.2056 - learning_rate: 1.8000e-04
# Epoch 29/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 21.5600 - mae: 10.1005 - mse: 234.1571 - val_loss: 36.7862 - val_mae: 19.1089 - val_mse: 675.9406 - learning_rate: 1.8000e-04
# Epoch 30/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - loss: 21.2441 - mae: 9.9638 - mse: 222.1382 - val_loss: 38.2241 - val_mae: 19.8257 - val_mse: 718.8319 - learning_rate: 1.8000e-04
# Epoch 31/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - loss: 20.8655 - mae: 9.7901 - mse: 214.6057 - val_loss: 36.2867 - val_mae: 18.8524 - val_mse: 680.9532 - learning_rate: 1.8000e-04
# Epoch 32/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 20.8162 - mae: 9.7676 - mse: 212.1097
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.00010800000163726508.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - loss: 20.8138 - mae: 9.7666 - mse: 212.0881 - val_loss: 35.9692 - val_mae: 18.6912 - val_mse: 668.0117 - learning_rate: 1.8000e-04
# Epoch 33/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - loss: 19.9519 - mae: 9.3934 - mse: 197.1710 - val_loss: 36.5846 - val_mae: 19.0019 - val_mse: 675.3840 - learning_rate: 1.0800e-04
# Epoch 34/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 19.2782 - mae: 9.0984 - mse: 189.5878 - val_loss: 37.0281 - val_mae: 19.2187 - val_mse: 685.7006 - learning_rate: 1.0800e-04
# Epoch 35/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - loss: 19.3081 - mae: 9.1150 - mse: 187.4535 - val_loss: 35.7878 - val_mae: 18.5989 - val_mse: 649.9979 - learning_rate: 1.0800e-04
# Epoch 36/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - loss: 18.9027 - mae: 8.9290 - mse: 178.6076 - val_loss: 36.1176 - val_mae: 18.7664 - val_mse: 662.3127 - learning_rate: 1.0800e-04
# Epoch 37/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - loss: 19.1000 - mae: 9.0110 - mse: 179.4766 - val_loss: 36.7544 - val_mae: 19.0893 - val_mse: 677.6455 - learning_rate: 1.0800e-04
# Epoch 38/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 18.6914 - mae: 8.8209 - mse: 174.3092 - val_loss: 37.0613 - val_mae: 19.2459 - val_mse: 687.2751 - learning_rate: 1.0800e-04
# Epoch 39/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 18.5542 - mae: 8.7727 - mse: 172.7896 - val_loss: 36.9515 - val_mae: 19.1856 - val_mse: 680.4348 - learning_rate: 1.0800e-04
# Epoch 40/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - loss: 18.1142 - mae: 8.6056 - mse: 158.5145 - val_loss: 38.0140 - val_mae: 19.7188 - val_mse: 729.5718 - learning_rate: 1.0800e-04
# Epoch 41/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 17.9365 - mae: 8.5116 - mse: 162.8796 - val_loss: 37.4277 - val_mae: 19.4250 - val_mse: 696.1077 - learning_rate: 1.0800e-04
# Epoch 42/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 18.0834 - mae: 8.5661 - mse: 159.4588 - val_loss: 37.1740 - val_mae: 19.2994 - val_mse: 704.7272 - learning_rate: 1.0800e-04
# Epoch 43/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 17.6094 - mae: 8.3598 - mse: 152.6152 - val_loss: 37.1488 - val_mae: 19.2866 - val_mse: 698.5381 - learning_rate: 1.0800e-04
# Epoch 44/250
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 17.6068 - mae: 8.3664 - mse: 148.6377
# Epoch 44: ReduceLROnPlateau reducing learning rate to 6.480000010924413e-05.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 17.6052 - mae: 8.3657 - mse: 148.6083 - val_loss: 36.4668 - val_mae: 18.9455 - val_mse: 674.2121 - learning_rate: 1.0800e-04
# Epoch 45/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - loss: 17.5213 - mae: 8.3137 - mse: 149.8217 - val_loss: 36.8456 - val_mae: 19.1339 - val_mse: 688.6729 - learning_rate: 6.4800e-05
# Epoch 46/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - loss: 16.9738 - mae: 8.0834 - mse: 141.4843 - val_loss: 37.3377 - val_mae: 19.3826 - val_mse: 696.6748 - learning_rate: 6.4800e-05
# Epoch 47/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 16.9634 - mae: 8.0886 - mse: 142.6555 - val_loss: 35.9929 - val_mae: 18.7061 - val_mse: 645.7372 - learning_rate: 6.4800e-05
# Epoch 48/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 17.2251 - mae: 8.1927 - mse: 147.8759 - val_loss: 36.7589 - val_mae: 19.0901 - val_mse: 680.4590 - learning_rate: 6.4800e-05
# Fold 3 → MAE: 16.5830 | RMSE: 23.7067 | R²: 0.7982
#
# ========================= FOLD 4/5 =========================
# Epoch 1/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 152.7677 - mae: 66.4197 - mse: 6750.7573
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 54ms/step - loss: 152.6464 - mae: 66.3632 - mse: 6740.3677 - val_loss: 89.6599 - val_mae: 45.5737 - val_mse: 2814.7874 - learning_rate: 3.0000e-04
# Epoch 2/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 87.5636 - mae: 37.7758 - mse: 2189.7534
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 87.4763 - mae: 37.7418 - mse: 2186.8076 - val_loss: 47.7536 - val_mae: 24.6041 - val_mse: 1041.4287 - learning_rate: 3.0000e-04
# Epoch 3/250
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 54.7241 - mae: 24.8073 - mse: 1095.2937
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 54.7066 - mae: 24.8002 - mse: 1094.8707 - val_loss: 45.3637 - val_mae: 23.4033 - val_mse: 975.0814 - learning_rate: 3.0000e-04
# Epoch 4/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 50.3109 - mae: 22.9354 - mse: 970.2448 - val_loss: 50.8725 - val_mae: 26.1611 - val_mse: 1183.7437 - learning_rate: 3.0000e-04
# Epoch 5/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 48.1559 - mae: 21.9881 - mse: 912.4542
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 48ms/step - loss: 48.1499 - mae: 21.9854 - mse: 912.2776 - val_loss: 42.0026 - val_mae: 21.7183 - val_mse: 927.6868 - learning_rate: 3.0000e-04
# Epoch 6/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 45.8344 - mae: 20.9569 - mse: 835.0038
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - loss: 45.8299 - mae: 20.9549 - mse: 834.8747 - val_loss: 40.0696 - val_mae: 20.7498 - val_mse: 809.9074 - learning_rate: 3.0000e-04
# Epoch 7/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 41.8299 - mae: 19.1771 - mse: 718.9514
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - loss: 41.8283 - mae: 19.1764 - mse: 718.8998 - val_loss: 38.2852 - val_mae: 19.8567 - val_mse: 737.0843 - learning_rate: 3.0000e-04
# Epoch 8/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 40.2830 - mae: 18.4882 - mse: 678.7568
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 40.2852 - mae: 18.4891 - mse: 678.7977 - val_loss: 36.8461 - val_mae: 19.1381 - val_mse: 727.9761 - learning_rate: 3.0000e-04
# Epoch 9/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 39.2936 - mae: 18.0271 - mse: 653.4420
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 39.2901 - mae: 18.0257 - mse: 653.3524 - val_loss: 33.5788 - val_mae: 17.4997 - val_mse: 584.5334 - learning_rate: 3.0000e-04
# Epoch 10/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 36.8390 - mae: 16.9500 - mse: 592.1677 - val_loss: 35.3573 - val_mae: 18.3913 - val_mse: 636.3607 - learning_rate: 3.0000e-04
# Epoch 11/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 35.7543 - mae: 16.4796 - mse: 549.9041
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 9s 50ms/step - loss: 35.7503 - mae: 16.4777 - mse: 549.8580 - val_loss: 33.1193 - val_mae: 17.2716 - val_mse: 545.3134 - learning_rate: 3.0000e-04
# Epoch 12/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 34.2592 - mae: 15.8017 - mse: 514.2606 - val_loss: 36.5953 - val_mae: 19.0068 - val_mse: 654.7327 - learning_rate: 3.0000e-04
# Epoch 13/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 33.3531 - mae: 15.4090 - mse: 495.4693 - val_loss: 33.6045 - val_mae: 17.5037 - val_mse: 562.3235 - learning_rate: 3.0000e-04
# Epoch 14/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 32.3989 - mae: 14.9815 - mse: 475.6539 - val_loss: 37.4757 - val_mae: 19.4457 - val_mse: 700.6046 - learning_rate: 3.0000e-04
# Epoch 15/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 30.8062 - mae: 14.2567 - mse: 435.6194 - val_loss: 34.9762 - val_mae: 18.1990 - val_mse: 598.7447 - learning_rate: 3.0000e-04
# Epoch 16/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 30.1098 - mae: 13.9198 - mse: 416.3247
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - loss: 30.1059 - mae: 13.9180 - mse: 416.2371 - val_loss: 31.5545 - val_mae: 16.4802 - val_mse: 514.3036 - learning_rate: 3.0000e-04
# Epoch 17/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - loss: 28.7956 - mae: 13.3651 - mse: 384.9285 - val_loss: 35.8215 - val_mae: 18.6079 - val_mse: 663.9703 - learning_rate: 3.0000e-04
# Epoch 18/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 27.8473 - mae: 12.9356 - mse: 358.1982 - val_loss: 33.5154 - val_mae: 17.4605 - val_mse: 563.7366 - learning_rate: 3.0000e-04
# Epoch 19/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 27.2640 - mae: 12.6794 - mse: 343.4647 - val_loss: 34.0697 - val_mae: 17.7305 - val_mse: 588.8101 - learning_rate: 3.0000e-04
# Epoch 20/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 48ms/step - loss: 25.6906 - mae: 11.9544 - mse: 301.4434 - val_loss: 36.2650 - val_mae: 18.8397 - val_mse: 633.4746 - learning_rate: 3.0000e-04
# Epoch 21/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - loss: 24.9111 - mae: 11.6258 - mse: 287.4947 - val_loss: 33.5257 - val_mae: 17.4640 - val_mse: 556.1576 - learning_rate: 3.0000e-04
# Epoch 22/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - loss: 25.0446 - mae: 11.6803 - mse: 284.7235 - val_loss: 33.0830 - val_mae: 17.2396 - val_mse: 571.6164 - learning_rate: 3.0000e-04
# Epoch 23/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 48ms/step - loss: 23.7868 - mae: 11.1107 - mse: 264.3455 - val_loss: 35.4150 - val_mae: 18.4093 - val_mse: 619.1993 - learning_rate: 3.0000e-04
# Epoch 24/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 9s 44ms/step - loss: 23.4003 - mae: 10.9379 - mse: 247.9093 - val_loss: 39.5464 - val_mae: 20.4743 - val_mse: 754.9031 - learning_rate: 3.0000e-04
# Epoch 25/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 23.6970 - mae: 11.0589 - mse: 251.6733 - val_loss: 37.8419 - val_mae: 19.6105 - val_mse: 707.0185 - learning_rate: 3.0000e-04
# Epoch 26/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 22.2537 - mae: 10.4246 - mse: 223.5434 - val_loss: 35.6568 - val_mae: 18.5193 - val_mse: 634.9802 - learning_rate: 3.0000e-04
# Epoch 27/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 21.2293 - mae: 9.9910 - mse: 203.7319 - val_loss: 37.1460 - val_mae: 19.2666 - val_mse: 667.6512 - learning_rate: 3.0000e-04
# Epoch 28/250
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 20.8029 - mae: 9.7847 - mse: 192.3907
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.00018000000854954124.
# ...
# Fold 4 → MAE: 16.4802 | RMSE: 22.6783 | R²: 0.8144
#
# ========================= FOLD 5/5 =========================
# Epoch 1/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 158.7307 - mae: 69.2805 - mse: 7267.6875
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 17s 48ms/step - loss: 158.6099 - mae: 69.2239 - mse: 7257.2217 - val_loss: 90.4608 - val_mae: 45.9727 - val_mse: 2915.9768 - learning_rate: 3.0000e-04
# Epoch 2/250
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 103.3463 - mae: 43.8184 - mse: 2743.2634
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 48ms/step - loss: 103.1920 - mae: 43.7605 - mse: 2737.8401 - val_loss: 55.0675 - val_mae: 28.2706 - val_mse: 1367.8580 - learning_rate: 3.0000e-04
# Epoch 3/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 63.2817 - mae: 28.5005 - mse: 1372.7384
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - loss: 63.2660 - mae: 28.4937 - mse: 1372.1357 - val_loss: 47.3027 - val_mae: 24.3796 - val_mse: 1087.1599 - learning_rate: 3.0000e-04
# Epoch 4/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 55.1852 - mae: 25.0171 - mse: 1082.2083
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - loss: 55.1770 - mae: 25.0138 - mse: 1081.9690 - val_loss: 46.1587 - val_mae: 23.8050 - val_mse: 1052.8688 - learning_rate: 3.0000e-04
# Epoch 5/250
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 51.7708 - mae: 23.5982 - mse: 983.9124
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 48ms/step - loss: 51.7557 - mae: 23.5917 - mse: 983.4876 - val_loss: 40.1254 - val_mae: 20.7875 - val_mse: 863.9078 - learning_rate: 3.0000e-04
# Epoch 6/250
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 47.5219 - mae: 21.7452 - mse: 858.1536
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - loss: 47.5142 - mae: 21.7420 - mse: 858.0065 - val_loss: 37.9641 - val_mae: 19.6995 - val_mse: 836.0757 - learning_rate: 3.0000e-04
# Epoch 7/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 44.1861 - mae: 20.2420 - mse: 763.6155
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 48ms/step - loss: 44.1812 - mae: 20.2399 - mse: 763.4496 - val_loss: 37.3438 - val_mae: 19.3849 - val_mse: 822.0171 - learning_rate: 3.0000e-04
# Epoch 8/250
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 41.2675 - mae: 18.8959 - mse: 670.5008
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 9s 49ms/step - loss: 41.2619 - mae: 18.8938 - mse: 670.3669 - val_loss: 34.6160 - val_mae: 18.0223 - val_mse: 729.3917 - learning_rate: 3.0000e-04
# Epoch 9/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 39.0668 - mae: 17.9575 - mse: 612.2668
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 39.0632 - mae: 17.9560 - mse: 612.1996 - val_loss: 33.7540 - val_mae: 17.5862 - val_mse: 700.9288 - learning_rate: 3.0000e-04
# Epoch 10/250
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 36.4657 - mae: 16.7971 - mse: 550.9199
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 48ms/step - loss: 36.4630 - mae: 16.7960 - mse: 550.8922 - val_loss: 32.7483 - val_mae: 17.0830 - val_mse: 674.7368 - learning_rate: 3.0000e-04
# Epoch 11/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 35.1963 - mae: 16.2352 - mse: 515.6974 - val_loss: 35.1412 - val_mae: 18.2824 - val_mse: 747.0710 - learning_rate: 3.0000e-04
# Epoch 12/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 35.5785 - mae: 16.4168 - mse: 522.6443 - val_loss: 34.4781 - val_mae: 17.9502 - val_mse: 716.6373 - learning_rate: 3.0000e-04
# Epoch 13/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 33.6664 - mae: 15.5539 - mse: 474.2214
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 48ms/step - loss: 33.6638 - mae: 15.5526 - mse: 474.1568 - val_loss: 31.5373 - val_mae: 16.4820 - val_mse: 625.8236 - learning_rate: 3.0000e-04
# Epoch 14/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 31.5466 - mae: 14.6113 - mse: 426.8058 - val_loss: 34.4419 - val_mae: 17.9350 - val_mse: 692.8636 - learning_rate: 3.0000e-04
# Epoch 15/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 31.3221 - mae: 14.4892 - mse: 417.2917 - val_loss: 34.8066 - val_mae: 18.1150 - val_mse: 714.7324 - learning_rate: 3.0000e-04
# Epoch 16/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 30.6514 - mae: 14.2068 - mse: 401.6670 - val_loss: 34.6148 - val_mae: 18.0135 - val_mse: 709.9680 - learning_rate: 3.0000e-04
# Epoch 17/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 29.4790 - mae: 13.6647 - mse: 368.2833 - val_loss: 34.2306 - val_mae: 17.8315 - val_mse: 678.6584 - learning_rate: 3.0000e-04
# Epoch 18/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - loss: 29.0944 - mae: 13.4866 - mse: 363.6636 - val_loss: 34.0674 - val_mae: 17.7416 - val_mse: 702.5589 - learning_rate: 3.0000e-04
# Epoch 19/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - loss: 28.0078 - mae: 13.0224 - mse: 334.8648 - val_loss: 34.2360 - val_mae: 17.8250 - val_mse: 710.8299 - learning_rate: 3.0000e-04
# Epoch 20/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 26.6399 - mae: 12.4118 - mse: 315.9661 - val_loss: 36.1543 - val_mae: 18.7881 - val_mse: 763.6132 - learning_rate: 3.0000e-04
# Epoch 21/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 26.3844 - mae: 12.3162 - mse: 306.5178 - val_loss: 35.8195 - val_mae: 18.6256 - val_mse: 753.8884 - learning_rate: 3.0000e-04
# Epoch 22/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 26.4323 - mae: 12.3162 - mse: 305.9734 - val_loss: 37.7768 - val_mae: 19.6011 - val_mse: 795.9677 - learning_rate: 3.0000e-04
# Epoch 23/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - loss: 24.3805 - mae: 11.4281 - mse: 267.4534 - val_loss: 36.7100 - val_mae: 19.0628 - val_mse: 770.2269 - learning_rate: 3.0000e-04
# Epoch 24/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - loss: 24.5968 - mae: 11.5062 - mse: 268.7444 - val_loss: 36.6342 - val_mae: 19.0252 - val_mse: 777.1512 - learning_rate: 3.0000e-04
# Epoch 25/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 23.9392 - mae: 11.2049 - mse: 253.7812
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.00018000000854954124.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 23.9373 - mae: 11.2041 - mse: 253.7348 - val_loss: 38.0128 - val_mae: 19.7147 - val_mse: 813.8895 - learning_rate: 3.0000e-04
# Epoch 26/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 21.9075 - mae: 10.3222 - mse: 223.9328 - val_loss: 37.8603 - val_mae: 19.6407 - val_mse: 819.3037 - learning_rate: 1.8000e-04
# Epoch 27/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 21.5455 - mae: 10.1382 - mse: 208.3041 - val_loss: 37.8129 - val_mae: 19.6111 - val_mse: 823.1645 - learning_rate: 1.8000e-04
# Epoch 28/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 9s 49ms/step - loss: 21.1677 - mae: 9.9862 - mse: 195.5996 - val_loss: 38.0593 - val_mae: 19.7370 - val_mse: 832.8016 - learning_rate: 1.8000e-04
# Epoch 29/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 20.5992 - mae: 9.7431 - mse: 191.0010 - val_loss: 37.3138 - val_mae: 19.3716 - val_mse: 788.7314 - learning_rate: 1.8000e-04
# Epoch 30/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - loss: 20.2231 - mae: 9.5639 - mse: 182.2653 - val_loss: 38.6852 - val_mae: 20.0551 - val_mse: 838.0115 - learning_rate: 1.8000e-04
# Epoch 31/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 19.4636 - mae: 9.2241 - mse: 172.1145 - val_loss: 38.5171 - val_mae: 19.9685 - val_mse: 840.1661 - learning_rate: 1.8000e-04
# Epoch 32/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - loss: 19.4617 - mae: 9.2195 - mse: 173.2705 - val_loss: 37.2311 - val_mae: 19.3264 - val_mse: 791.6810 - learning_rate: 1.8000e-04
# Epoch 33/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - loss: 18.9535 - mae: 8.9856 - mse: 161.3610 - val_loss: 36.3391 - val_mae: 18.8788 - val_mse: 775.1710 - learning_rate: 1.8000e-04
# Epoch 34/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - loss: 18.9411 - mae: 8.9887 - mse: 162.9411 - val_loss: 38.2024 - val_mae: 19.8137 - val_mse: 805.4803 - learning_rate: 1.8000e-04
# Epoch 35/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - loss: 19.1132 - mae: 9.0543 - mse: 161.2078 - val_loss: 37.9205 - val_mae: 19.6689 - val_mse: 830.7138 - learning_rate: 1.8000e-04
# Epoch 36/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 18.0631 - mae: 8.5916 - mse: 148.1004 - val_loss: 38.2738 - val_mae: 19.8509 - val_mse: 817.8173 - learning_rate: 1.8000e-04
# Epoch 37/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 18.3875 - mae: 8.7294 - mse: 151.7458
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.00010800000163726508.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 48ms/step - loss: 18.3875 - mae: 8.7294 - mse: 151.7472 - val_loss: 38.5948 - val_mae: 20.0042 - val_mse: 826.5769 - learning_rate: 1.8000e-04
# Epoch 38/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - loss: 17.8307 - mae: 8.4777 - mse: 142.6839 - val_loss: 37.8610 - val_mae: 19.6353 - val_mse: 802.2604 - learning_rate: 1.0800e-04
# Epoch 39/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - loss: 17.2325 - mae: 8.2138 - mse: 138.0562 - val_loss: 36.4889 - val_mae: 18.9538 - val_mse: 782.5947 - learning_rate: 1.0800e-04
# Epoch 40/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 48ms/step - loss: 16.8588 - mae: 8.0693 - mse: 130.6618 - val_loss: 39.1160 - val_mae: 20.2713 - val_mse: 849.8875 - learning_rate: 1.0800e-04
# Epoch 41/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - loss: 16.9246 - mae: 8.0787 - mse: 129.6867 - val_loss: 36.9305 - val_mae: 19.1711 - val_mse: 791.7473 - learning_rate: 1.0800e-04
# Epoch 42/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 48ms/step - loss: 16.3571 - mae: 7.8316 - mse: 122.7484 - val_loss: 37.7802 - val_mae: 19.5980 - val_mse: 829.2693 - learning_rate: 1.0800e-04
# Epoch 43/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - loss: 16.6714 - mae: 7.9635 - mse: 128.0728 - val_loss: 37.9216 - val_mae: 19.6724 - val_mse: 832.7059 - learning_rate: 1.0800e-04
# Epoch 44/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 16.2834 - mae: 7.7932 - mse: 122.8469 - val_loss: 37.5904 - val_mae: 19.5090 - val_mse: 810.0637 - learning_rate: 1.0800e-04
# Epoch 45/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 48ms/step - loss: 16.7870 - mae: 8.0058 - mse: 129.2691 - val_loss: 37.1834 - val_mae: 19.2976 - val_mse: 812.4018 - learning_rate: 1.0800e-04
# Epoch 46/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - loss: 16.1860 - mae: 7.7612 - mse: 119.5481 - val_loss: 37.0513 - val_mae: 19.2377 - val_mse: 787.9819 - learning_rate: 1.0800e-04
# Epoch 47/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 48ms/step - loss: 16.2741 - mae: 7.7867 - mse: 120.9268 - val_loss: 37.7872 - val_mae: 19.6052 - val_mse: 813.3231 - learning_rate: 1.0800e-04
# Epoch 48/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 16.3680 - mae: 7.8359 - mse: 118.5464 - val_loss: 36.8227 - val_mae: 19.1175 - val_mse: 798.4261 - learning_rate: 1.0800e-04
# Epoch 49/250
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 15.7157 - mae: 7.5566 - mse: 112.6262
# Epoch 49: ReduceLROnPlateau reducing learning rate to 6.480000010924413e-05.
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - loss: 15.7166 - mae: 7.5568 - mse: 112.6263 - val_loss: 37.5154 - val_mae: 19.4655 - val_mse: 812.1850 - learning_rate: 1.0800e-04
# Epoch 50/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 48ms/step - loss: 15.3732 - mae: 7.3760 - mse: 108.9962 - val_loss: 37.2888 - val_mae: 19.3539 - val_mse: 821.5132 - learning_rate: 6.4800e-05
# Epoch 51/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - loss: 15.2761 - mae: 7.3373 - mse: 109.2072 - val_loss: 37.7698 - val_mae: 19.5966 - val_mse: 817.7813 - learning_rate: 6.4800e-05
# Epoch 52/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - loss: 15.4310 - mae: 7.4208 - mse: 108.7234 - val_loss: 36.5802 - val_mae: 19.0005 - val_mse: 788.1805 - learning_rate: 6.4800e-05
# Epoch 53/250
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 48ms/step - loss: 15.3842 - mae: 7.3840 - mse: 110.3886 - val_loss: 37.7722 - val_mae: 19.6016 - val_mse: 820.5590 - learning_rate: 6.4800e-05
# Fold 5 → MAE: 16.4820 | RMSE: 25.0165 | R²: 0.7739
#
# === Cross-Validation Summary ===
# Avg MAE: 16.1950 | Avg RMSE: 23.0829 | Avg R²: 0.8102
#
# Best Fold (by MAE): 2
# Best Fold (by R²) : 2  [MAE=15.1488, R²=0.8449]
#
# =======================================================
#   FINAL TEST RESULTS
# =======================================================
#   Single best model → MAE=15.0886  RMSE=22.0551  R²=0.8188
#   Full ensemble      → MAE=14.9720  RMSE=21.5254  R²=0.8274
#
#   → Using full ensemble predictions
#
# ✅ Final: MAE=14.9720  RMSE=21.5254  R²=0.8274
# 🏆 TARGET ACHIEVED: Test R² ≥ 0.80!
#
# === MAE by True RUL Bucket ===
#   RUL   0– 20: n= 40 | MAE=3.85 | Bias=+1.74
#   RUL  20– 40: n= 29 | MAE=5.75 | Bias=-2.08
#   RUL  40– 60: n= 21 | MAE=13.23 | Bias=+4.94
#   RUL  60– 80: n= 22 | MAE=16.65 | Bias=+11.18
#   RUL  80–110: n= 41 | MAE=18.65 | Bias=+0.07
#   RUL 110–200: n= 53 | MAE=25.56 | Bias=-21.42
#
# === Prediction Bias ===
#   Mean error (pred − true): -3.7538
#   Engines overpredicted   : 93
#   Engines underpredicted  : 113
#
# === True RUL Distribution ===
#   True RULs > 110 : 52 engines
#   True RULs > 125 : 38 engines
#   Max true RUL    : 195.0
#   Mean true RUL   : 75.8
